# %% [markdown]
# # Inference with FCNv2

# %% [markdown]
# ## Setup

# %%
import numpy as np
import datetime
import os
import matplotlib.pyplot as plt
import json

from scipy.signal import periodogram

# Set number of GPUs to use to 1
os.environ["WORLD_SIZE"] = "1"
# Set model registry as a local folder
model_registry = os.path.join(os.path.dirname(os.path.realpath(os.getcwd())), "models")
os.makedirs(model_registry, exist_ok=True)
os.environ["MODEL_REGISTRY"] = model_registry
print(f"{os.environ['MODEL_REGISTRY']}")
# With the enviroment variables set now we import Earth-2 MIP
from earth2mip import registry, inference_ensemble
from earth2mip.initial_conditions import cds
from earth2mip.networks.fcnv2_sm import load as fcnv2_sm_load
# Out:
# /home/workspace/FCN/earth2mip/models

# %% [markdown]
# # Run Full Inference

# %%
import logging
import os

# Ensure the logs directory exists
os.makedirs("logs", exist_ok=True)

# Configure logging
logging.basicConfig(
    filename=os.path.join("logs", "update_netcdf.log"),
    filemode='w',
    format='%(asctime)s - %(levelname)s - %(message)s',
    level=logging.DEBUG
)

# Create a logger object
logger = logging.getLogger()

# %%
from earth2mip.schema import EnsembleRun
from earth2mip.inference_ensemble import run_inference
import torch
import numpy as np
import earth2mip.initial_conditions
from earth2mip.schema import Grid, PerturbationStrategy

# Load model(s) from registry
package = registry.get_model("fcnv2_sm")
print("loading FCNv2 small model, this can take a bit")
model = fcnv2_sm_load(package)
perturb = None  # Use default perturbation if not specified
group = None  # Use default torch distributed group if not specified
progress = True  # Show progress bar
# Out:
# loading FCNv2 small model, this can take a bit

# %%
model.in_channel_names
# Out:
# ['u10m',
#  'v10m',
#  'u100m',
#  'v100m',
#  't2m',
#  'sp',
#  'msl',
#  'tcwv',
#  'u50',
#  'u100',
#  'u150',
#  'u200',
#  'u250',
#  'u300',
#  'u400',
#  'u500',
#  'u600',
#  'u700',
#  'u850',
#  'u925',
#  'u1000',
#  'v50',
#  'v100',
#  'v150',
#  'v200',
#  'v250',
#  'v300',
#  'v400',
#  'v500',
#  'v600',
#  'v700',
#  'v850',
#  'v925',
#  'v1000',
#  'z50',
#  'z100',
#  'z150',
#  'z200',
#  'z250',
#  'z300',
#  'z400',
#  'z500',
#  'z600',
#  'z700',
#  'z850',
#  'z925',
#  'z1000',
#  't50',
#  't100',
#  't150',
#  't200',
#  't250',
#  't300',
#  't400',
#  't500',
#  't600',
#  't700',
#  't850',
#  't925',
#  't1000',
#  'r50',
#  'r100',
#  'r150',
#  'r200',
#  'r250',
#  'r300',
#  'r400',
#  'r500',
#  'r600',
#  'r700',
#  'r850',
#  'r925',
#  'r1000']

# %%
from earth2mip.weather_events import WeatherEvent, WeatherEventProperties, Domain, Window, Diagnostic

"""# Define diagnostics
diagnostic = Diagnostic(type="raw", channels=["u100", "u200"], nbins=10)
data_source = cds.DataSource(model.in_channel_names)

# Define domains
window = Window(
    name="global",
    lat_min=-90,
    lat_max=90,
    lon_min=0,
    lon_max=360,
    diagnostics=[diagnostic]
)

# Define weather event properties
weather_event_properties = WeatherEventProperties(
    name="example_event7",
    start_time=datetime.datetime(2023, 5, 21),
    initial_condition_source='era5',
)

# Create WeatherEvent
weather_event = WeatherEvent(
    properties=weather_event_properties,
    domains=[window]
)"""

# EnsembleRun contains settings for the ensemble forecast
config = {
    "ensemble_members": 4,
    "noise_amplitude": 0.05,
    "simulation_length": 4,
    "weather_event": {
        "properties": {
            "name": "Globe",
            "start_time": "2023-07-01 00:00:00",
            "initial_condition_source": "cds",
        },
        "domains": [
            {
                "name": "global",
                "type": "Window",
                "diagnostics": [{"type": "raw", "channels": ["t2m", "u10m"]}],
            }
        ],
    },
    "output_path": "outputs/01_ensemble_notebook",
    "output_frequency": 1,
    "weather_model": "fcnv2_sm",
    "seed": 12345,
    "use_cuda_graphs": False,
    "ensemble_batch_size": 4,
    "autocast_fp16": False,
    "perturbation_strategy": "correlated",
    "noise_reddening": 2.0,
}

# %%
config_str = json.dumps(config)
inference_ensemble.main(config_str)
# Out:
# /root/miniconda3/envs/py3.11/lib/python3.11/site-packages/modulus/distributed/manager.py:285: UserWarning: Distributed manager is already intialized
#   warn("Distributed manager is already intialized")
# 2024-05-30 16:41:37,311 INFO Welcome to the CDS
# 2024-05-30 16:41:37,312 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-single-levels
# 2024-05-30 16:41:37,371 INFO Request is queued
# 2024-05-30 16:41:37,543 INFO Welcome to the CDS
# 2024-05-30 16:41:37,544 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels
# 2024-05-30 20:19:10,719 INFO Request is running
# 2024-05-30 20:21:10,824 INFO Request is queued
# 2024-05-30 20:21:10,876 INFO Request is running
# 2024-05-30 20:23:10,996 INFO Request is queued
# 2024-05-30 20:23:11,253 INFO Request is running
# 2024-05-30 20:25:11,132 INFO Request is queued
# 2024-05-30 20:25:11,283 INFO Request is running
# 2024-05-30 20:27:11,464 INFO Request is queued
# 2024-05-30 20:27:12,198 INFO Request is running
# 2024-05-30 20:29:12,645 INFO Request is queued
# 2024-05-30 20:29:12,842 INFO Request is running
# 2024-05-30 20:31:13,381 INFO Request is queued
# 2024-05-30 20:31:14,070 INFO Request is running
# 2024-05-30 20:33:16,060 INFO Request is queued
# 2024-05-30 20:35:16,853 INFO Request is running
# 2024-05-30 20:35:16,917 INFO Request is queued
# 2024-05-30 20:37:17,800 INFO Request is running
# 2024-05-30 20:37:18,641 INFO Request is queued
# 2024-05-30 20:39:18,674 INFO Request is running
# 2024-05-30 20:41:18,848 INFO Request is queued
# 2024-05-30 20:41:19,087 INFO Request is running
# 2024-05-30 20:43:20,026 INFO Request is queued
# 2024-05-30 20:43:20,742 INFO Request is running
# 2024-05-30 20:45:21,238 INFO Request is completed
# 2024-05-30 20:45:21,244 INFO Downloading https://download-0010-clone.copernicus-climate.eu/cache-compute-0010/cache/data2/adaptor.mars.internal-1717094689.2141016-3245-10-4f11147d-3fcf-48d4-b7e4-83597687e336.grib to /root/.cache/earth2mip/cds/6f280c4e95f8f3a014f441335c6d319ab1eaa3d5be972c0f6255f6583af0b041/reanalysis-era5-single-levels.grib.tmp (15.8M)
# 2024-05-30 20:45:27,818 INFO Download rate 2.4M/s
# 2024-05-30 20:47:21,795 INFO Request is running
# 2024-05-30 20:51:22,707 INFO Request is queued
# 2024-05-30 20:53:24,881 INFO Request is running
# 2024-05-30 20:57:25,844 INFO Request is queued
# 2024-05-30 20:59:26,947 INFO Request is running
# 2024-05-30 21:05:34,165 INFO Request is queued
# 2024-05-30 21:07:35,001 INFO Request is running
# 2024-05-30 21:09:35,518 INFO Request is completed
# 2024-05-30 21:09:35,519 INFO Downloading https://download-0015-clone.copernicus-climate.eu/cache-compute-0015/cache/data2/adaptor.mars.internal-1717096075.6319277-31038-10-9fe435d6-a4bf-4804-980d-c5fd8ad74bda.grib to /root/.cache/earth2mip/cds/a1e09e309f6c43944115428c425dfab7cb0c9244b9a08ca160fea9e440f4cce5/reanalysis-era5-pressure-levels.grib.tmp (128.7M)
# 2024-05-30 22:30:44,927 INFO Download rate 27.1K/s
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 config_str = json.dumps(config)
# ----> 2 inference_ensemble.main(config_str)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/inference_ensemble.py:205, in main(config)
#     200 perturb = get_initializer(
#     201     model,
#     202     config,
#     203 )
#     204 logging.info("Running inference")
# --> 205 run_inference(model, config, perturb, group)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/inference_ensemble.py:382, in run_inference(model, config, perturb, group, progress, data_source)
#     379     nc.institution = "NVIDIA"
#     380     nc.Conventions = "CF-1.10"
# --> 382     run_ensembles(
#     383         weather_event=weather_event,
#     384         model=model,
#     385         perturb=perturb,
#     386         nc=nc,
#     387         domains=weather_event.domains,
#     388         x=x,
#     389         n_ensemble=n_ensemble,
#     390         n_steps=config.simulation_length,
#     391         output_frequency=config.output_frequency,
#     392         batch_size=config.ensemble_batch_size,
#     393         rank=dist.rank,
#     394         date_obj=date_obj,
#     395         restart_frequency=config.restart_frequency,
#     396         output_path=output_path,
#     397         output_grid=(
#     398             earth2mip.grid.from_enum(config.output_grid)
#     399             if config.output_grid
#     400             else None
#     401         ),
#     402         progress=progress,
#     403     )
#     404 if torch.distributed.is_initialized():
#     405     torch.distributed.barrier(group)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/inference_ensemble.py:130, in run_ensembles(n_steps, weather_event, model, perturb, x, nc, domains, n_ensemble, batch_size, rank, output_frequency, output_grid, date_obj, restart_frequency, output_path, restart_initial_directory, progress)
#     126 time_count = -1
#     128 # for time, data, restart in iterator:
# --> 130 for k, (time, data, _) in enumerate(iterator):
#     131     # if restart_frequency and k % restart_frequency == 0:
#     132     #     save_restart(
#     133     #         restart,
#     134     #         rank,
#     135     #         batch_id,
#     136     #         path=os.path.join(output_path, "restart", time.isoformat()),
#     137     #     )
#     138
#     139     # Saving the output
#     140     if output_frequency and k % output_frequency == 0:
#     141         time_count += 1
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/__init__.py:215, in Inference.__call__(self, time, x, restart, normalize)
#     213     yield from self._iterate(**restart)
#     214 else:
# --> 215     yield from self._iterate(x=x, time=time)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/__init__.py:244, in Inference._iterate(self, x, normalize, time)
#     242     dt = torch.tensor(self.time_step.total_seconds())
#     243     x += self.source(x_with_units, time) / self.scale * dt
# --> 244 x = self.model(x, time)
#     245 time = time + self.time_step
#     247 # create args and kwargs for future use
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/__init__.py:113, in _SimpleModelAdapter.forward(self, x, time)
#     111     y = self.model.forward(x, time)
#     112 else:
# --> 113     y = self.model.forward(x)
#     115 if not self.has_history:
#     116     y = y[:, None]
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/fcnv2/sfnonet.py:551, in FourierNeuralOperatorNet.forward(self, x)
#     548 x = x + self.pos_embed
#     550 # forward features
# --> 551 x = self.forward_features(x)
#     553 # concatenate the big skip
#     554 if self.big_skip:
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/fcnv2/sfnonet.py:535, in FourierNeuralOperatorNet.forward_features(self, x)
#     532 x = self.pos_drop(x)
#     534 for blk in self.blocks:
# --> 535     x = blk(x)
#     537 return x
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/fcnv2/sfnonet.py:212, in FourierNeuralOperatorBlock.forward(self, x)
#     209 residual = x
#     211 x = self.norm0(x)
# --> 212 x = self.filter_layer(x).contiguous()
#     214 if hasattr(self, "inner_skip"):
#     215     if self.concat_skip:
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/fcnv2/sfnonet.py:120, in SpectralFilterLayer.forward(self, x)
#     119 def forward(self, x):
# --> 120     return self.filter(x)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/earth2mip/networks/fcnv2/layers.py:651, in SpectralAttentionS2.forward(self, x)
#     649 with amp.autocast(enabled=False):
#     650     x = torch.view_as_complex(x)
# --> 651     x = self.inverse_transform(x)
#     652     x = x.to(dtype)
#     654 return x
#
# File ~/miniconda3/envs/py3.11/lib/python3.11/site-packages/torch_harmonics/sht.py:196, in InverseRealSHT.forward(self, x)
#     194 # apply the inverse (real) FFT
#     195 x = torch.view_as_complex(xs)
# --> 196 x = torch.fft.irfft(x, n=self.nlon, dim=-1, norm="forward")
#     198 return x
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 3.96 GiB. GPU

# %% [markdown]
# # Step 3: Call the run_inference function with the modified config
# run_inference(
#     model=model,
#     config=config,
#     perturb=perturb,
#     group=group,
#     progress=progress,
#     data_source=data_source
# )

# %% [markdown]
# # Process Output Data

# %%
import xarray
def open_ensemble(f, domain, chunks={"time": 1}):
    time = xarray.open_dataset(f).time
    root = xarray.open_dataset(f, decode_times=False)
    ds = xarray.open_dataset(f, chunks=chunks, group=domain)
    ds.attrs = root.attrs
    return ds.assign_coords(time=time)


output_path = config["output_path"]
domains = config["weather_event"]["domains"][0]["name"]
ensemble_members = config["ensemble_members"]
ds = open_ensemble(os.path.join(output_path, "ensemble_out_0.nc"), domains)
ds
# Out:
# <xarray.Dataset> Size: 731MB
# Dimensions:  (lat: 721, lon: 1440, ensemble: 4, time: 11)
# Coordinates:
#   * lat      (lat) float32 3kB 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * lon      (lon) float32 6kB 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#   * time     (time) datetime64[ns] 88B 2018-06-01 ... 2018-06-03T12:00:00
# Dimensions without coordinates: ensemble
# Data variables:
#     imin     int64 8B ...
#     imax     int64 8B ...
#     jmin     int64 8B ...
#     jmax     int64 8B ...
#     t2m      (ensemble, time, lat, lon) float64 365MB dask.array<chunksize=(2, 1, 361, 720), meta=np.ndarray>
#     u10m     (ensemble, time, lat, lon) float64 365MB dask.array<chunksize=(2, 1, 361, 720), meta=np.ndarray>
# Attributes:
#     model:          fcnv2_sm
#     config:         {"weather_model": "fcnv2_sm", "simulation_length": 10, "p...
#     weather_event:  {"properties": {"name": "Globe", "start_time": "2018-06-0...
#     date_created:   2024-05-27T19:05:25.525498
#     history:        /root/miniconda3/envs/py3.11/lib/python3.11/site-packages...
#     institution:    NVIDIA
#     Conventions:    CF-1.10

# %% [markdown]
# # Post Processing

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import TwoSlopeNorm

countries = cfeature.NaturalEarthFeature(
    category="cultural",
    name="admin_0_countries",
    scale="50m",
    facecolor="none",
    edgecolor="black",
)

# Assuming ds is your xarray.Dataset and contains the data
plt.close("all")
fig = plt.figure(figsize=(15, 10))
plt.rcParams["figure.dpi"] = 100

nyc_lat = 40
nyc_lon = 360 - 74  # Adjusting longitude for dataset
proj = ccrs.NearsidePerspective(central_longitude=nyc_lon, central_latitude=nyc_lat)

# Data for the first ensemble member at the last time step
data = ds.t2m[0, -1, :, :]
norm = TwoSlopeNorm(vmin=220, vcenter=290, vmax=320)

ax = fig.add_subplot(131, projection=proj)
ax.set_title("First ensemble member t2m (K)")
img = ax.pcolormesh(
    ds.lon, ds.lat, data, transform=ccrs.PlateCarree(), norm=norm, cmap="seismic"
)
ax.coastlines(linewidth=1)
countries = cfeature.NaturalEarthFeature(
    category='cultural', name='admin_0_countries', scale='50m', facecolor='none'
)
ax.add_feature(countries, edgecolor="black", linewidth=0.25)
plt.colorbar(img, ax=ax, shrink=0.40, norm=mcolors.CenteredNorm(vcenter=0))
gl = ax.gridlines(draw_labels=True, linestyle="--")

plt.savefig(f"{output_path}/first_ensemble_member_t2m.png")

# %%
plt.close("all")
lead_time = np.array(
    (pd.to_datetime(ds.time) - pd.to_datetime(ds.time)[0]).total_seconds() / 3600
)
nyc_lat = 40
nyc_lon = 360 - 74
NYC = ds.sel(lon=nyc_lon, lat=nyc_lat)
fig = plt.figure(figsize=(9, 6))
ax = fig.add_subplot(311)
ax.set_title("Ensemble members")
ax.plot(lead_time, NYC.u10m.T)
ax.set_ylabel("u10m [m/s]")

ax = fig.add_subplot(312)
ax.set_title("deviation from ensemble mean")
ax.plot(lead_time, NYC.t2m.T - NYC.t2m.mean("ensemble"))
ax.set_ylabel("t2m deviation [°C]")

ax = fig.add_subplot(313)
ax.set_title("ensemble spread")
ax.plot(lead_time, NYC.t2m.std("ensemble"))
ax.set_xlabel("lead_time [h]")
ax.set_ylabel("std u10m [m/s]")
plt.tight_layout()
plt.savefig(f"{output_path}/new_york_zonal_winds.png")

# %%
plt.close("all")
fig = plt.figure(figsize=(15, 10))
plt.rcParams["figure.dpi"] = 100
proj = ccrs.NearsidePerspective(central_longitude=nyc_lon, central_latitude=nyc_lat)

data = ds.t2m[0, -1, :, :]
norm = TwoSlopeNorm(vmin=220, vcenter=290, vmax=320)
ax = fig.add_subplot(131, projection=proj)
ax.set_title("First ensemble member t2m (K)")
img = ax.pcolormesh(
    ds.lon, ds.lat, data, transform=ccrs.PlateCarree(), norm=norm, cmap="seismic"
)
ax.coastlines(linewidth=1)
ax.add_feature(countries, edgecolor="black", linewidth=0.25)
plt.colorbar(img, ax=ax, shrink=0.40, norm=mcolors.CenteredNorm(vcenter=0))
gl = ax.gridlines(draw_labels=True, linestyle="--")

data = ds.t2m[-1, -1, :, :]
norm = TwoSlopeNorm(vmin=220, vcenter=290, vmax=320)
ax = fig.add_subplot(132, projection=proj)
plt.rcParams["figure.dpi"] = 100
proj = ccrs.NearsidePerspective(central_longitude=nyc_lon, central_latitude=nyc_lat)
ax.set_title("Last ensemble member t2m (K)")
img = ax.pcolormesh(
    ds.lon, ds.lat, data, transform=ccrs.PlateCarree(), norm=norm, cmap="seismic"
)
ax.coastlines(linewidth=1)
ax.add_feature(countries, edgecolor="black", linewidth=0.25)
plt.colorbar(img, ax=ax, shrink=0.40, norm=mcolors.CenteredNorm(vcenter=0))
gl = ax.gridlines(draw_labels=True, linestyle="--")

ds_ensemble_std = ds.std(dim="ensemble")
data = ds_ensemble_std.t2m[-1, :, :]
# norm = TwoSlopeNorm(vmin=data.min().values, vcenter=5, vmax=data.max().values)
proj = ccrs.NearsidePerspective(central_longitude=nyc_lon, central_latitude=nyc_lat)
ax = fig.add_subplot(133, projection=proj)
ax.set_title("ensemble std  t2m (K)")
img = ax.pcolormesh(ds.lon, ds.lat, data, transform=ccrs.PlateCarree(), cmap="seismic")
ax.coastlines(linewidth=1)
ax.add_feature(countries, edgecolor="black", linewidth=0.25)
plt.colorbar(img, ax=ax, shrink=0.40, norm=mcolors.CenteredNorm(vcenter=0))
gl = ax.gridlines(draw_labels=True, linestyle="--")
plt.savefig(f"{output_path}/gloabl_surface_temp_contour.png")
